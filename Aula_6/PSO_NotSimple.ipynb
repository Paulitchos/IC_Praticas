# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plot
from IPython.display import Image
# Import PySwarms
import pyswarms as ps
from pyswarms.utils.functions import single_obj as fx
from pyswarms.utils.plotters import (plot_cost_history,plot_contour,plot_surface)
from pyswarms.utils.plotters.formatters import Mesher
from pyswarms.backend.topology import Pyramid

# Set-up hyperparameters
options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}
# Call instance of PSO
optimizer = ps.single.GlobalBestPSO(n_particles=10, dimensions=2, options=options)
# Perform optimization
stats = optimizer.optimize(fx.sphere,iters = 100)

print(stats)

#Obtain cost history from optimizer instance

cost_history = optimizer.cost_history

#Plot
plot_cost_history(cost_history)

#Initialize mesher with sphere function
m = Mesher(func=fx.sphere)

#Make animation
animation = plot_contour(pos_history=optimizer.pos_history,mesher=m,mark=(0,0))

#Enables us to view it in a Jupyter notebook
animation.save('Star.gif',writer='imagemagick',fps=10)
Image(url='Star.gif')

#-----------------------------------------------------------------------------#

# Set-up hyperparameters
options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}
m_topology = Pyramid(static=False) # In this topology, the particles are connected by N-dimensional
# Call instance of PSO
optimizer = ps.single.GeneralOptimizerPSO(n_particles=10, dimensions=2, options=options,topology = m_topology)
# Perform optimization
stats = optimizer.optimize(fx.sphere,iters = 100)

print(stats)

#Obtain cost history from optimizer instance

cost_history = optimizer.cost_history

#Plot
plot_cost_history(cost_history)

#Initialize mesher with sphere function
m = Mesher(func=fx.sphere)

#Make animation
animation = plot_contour(pos_history=optimizer.pos_history,mesher=m,mark=(0,0))

#Enables us to view it in a Jupyter notebook
animation.save('Pyramid.gif',writer='imagemagick',fps=10)
Image(url='Pyramid.gif')
# Out:
# 2022-11-29 15:46:01,033 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=1.14e-6
# 2022-11-29 15:46:01,161 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.1408792579512218e-06, best pos: [ 0.00106235 -0.00011083]
# (1.1408792579512218e-06, array([ 0.00106235, -0.00011083]))
# 2022-11-29 15:46:03,602 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.ImageMagickWriter'>
# 2022-11-29 15:46:03,604 - matplotlib.animation - INFO - MovieWriter._run: running command: convert -size 1000x800 -depth 8 -delay 10.0 -loop 0 rgba:- -layers OptimizePlus Star.gif
# 2022-11-29 15:47:12,407 - pyswarms.single.general_optimizer - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.general_optimizer:   0%|          |0/100/home/paulitchos/.local/lib/python3.10/site-packages/pyswarms/backend/topology/pyramid.py:81: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.neighbor_idx = np.array(
# pyswarms.single.general_optimizer: 100%|██████████|100/100, best_cost=5.09e-8
# 2022-11-29 15:47:12,583 - pyswarms.single.general_optimizer - INFO - Optimization finished | best cost: 5.087307018740785e-08, best pos: [ 2.12681036e-04 -7.50989147e-05]
# (5.087307018740785e-08, array([ 2.12681036e-04, -7.50989147e-05]))
# 2022-11-29 15:47:15,130 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.ImageMagickWriter'>
# 2022-11-29 15:47:15,131 - matplotlib.animation - INFO - MovieWriter._run: running command: convert -size 1000x800 -depth 8 -delay 10.0 -loop 0 rgba:- -layers OptimizePlus Pyramid.gif
# <img src="Pyramid.gif"/>
